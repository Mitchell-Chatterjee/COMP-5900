# %%
import os, glob
import matplotlib.pyplot as plt

# ..........support imports............
from SupportClasses import Data_support as ds
from SupportClasses import TCAV_support as ts
from SupportClasses import Model_support as ms

# ..........torch imports............
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn

# .... Captum imports..................
from captum.attr import LayerIntegratedGradients
from captum.concept import TCAV

# GLobal values
COLAB = False
NUM_OF_EPOCHS = 25
IMAGENET_IND_DICT = {'ants': 310, 'bees': 309, 'zebra':340}
CONCEPTS_PATH = "data/tcav/image/concepts/"
DATA_DIR = 'data/tcav/image/imagenet'
# End of Global values

# Modifiable Values
TARGET_CONCEPT = "striped"
TARGET_CLASS = "zebra"
# End of modifiable values

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# # Data Preparation

# %%
# Data pre-processing
ds.data_preprocessing(my_dir=CONCEPTS_PATH)

# %%
# Preliminary work for fine tuning the model.

# First get transformations for the imagenet data.
data_transforms = ds.return_data_transforms()

# Get imagenet datasets, apply transformations and create dataloaders.
image_datasets = ds.return_imagenet_dataset(data_dir=DATA_DIR, data_transforms=data_transforms)
dataloaders = ds.return_dataloaders(image_datasets=image_datasets)

# Other useful attributes we wish to extract from the data.
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes
print(f'Class names used for prediction: {class_names}')

# Get the device we are currently working with.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f'\nThe device used for this experiment: {device}')

# %% [markdown]
# # Model Preparation

# %%
# Preliminary work for setting up the model.

# Preparing the Googlenet model.
model = torchvision.models.googlenet(weights=torchvision.models.GoogLeNet_Weights.DEFAULT)
# Send model to the device we are using.
model.to(device=device)
# Out:
# cuda:0

# %%
# Preliminary work for setting up concepts.

# Selected concepts.
stripes_concept = ds.assemble_concept("striped", 0, concepts_path=CONCEPTS_PATH)
zigzagged_concept = ds.assemble_concept("zigzagged", 1, concepts_path=CONCEPTS_PATH)
dotted_concept = ds.assemble_concept("dotted", 2, concepts_path=CONCEPTS_PATH)

# Selecting the concepts we intend to query for the conceptual loss.
experimental_set = [stripes_concept, zigzagged_concept, dotted_concept]

# Select the layers for interpretation.
layers=['inception4c', 'inception4d', 'inception4e']

# Defining the TCAV model and which layers we intend to consider.
mytcav = TCAV(model=model,
              layers=layers,
              layer_attr_method = LayerIntegratedGradients(
                model, None, multiply_by_inputs=False))
# Out:
# D:\git\COMP-5900\venv\lib\site-packages\captum\concept\_utils\classifier.py:130: UserWarning: Using default classifier for TCAV which keeps input both train and test datasets in the memory. Consider defining your own classifier that doesn't rely heavily on memory, for large number of concepts, by extending `Classifer` abstract class
#   warnings.warn(

# %% [markdown]
# # Fine-Tuning the Model

# %%
# Fine tuning of the model.

# Here is where we want to fine tune the model.
num_ftrs = model.fc.in_features
# Here the size of each output sample is set to nn.Linear(num_ftrs, len(class_names)).
model.fc = nn.Linear(num_ftrs, len(class_names))
# Send the fine-tuned model to the device we are working with.
model_ft = model.to(device)

# Hyper-parameters for the model.
criterion = nn.CrossEntropyLoss()
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)
# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# Stand-in value:
conceptual_loss = None
# Out:
# ['ants', 'bees', 'zebra']

# %%
# Additional Hyper-parameters for including the conceptual loss.

# Loss term.
criterion_CL = nn.MSELoss()

# Get the key of the concept to be used for training.
concept_key = ts.get_concept_keys(experimental_set=experimental_set)

# TODO: Extract target class index.

# Create the conceptual loss class.
conceptual_loss = ts.ConceptualLoss(criterion=criterion, tcav_model=mytcav, experimental_set=experimental_set,
                                    target_concept_name=TARGET_CONCEPT, target_class_name=TARGET_CLASS,
                                    target_class_index=2, concept_key=concept_key)

# %%
# Training the model.

# Train the model.
model_ft = ms.train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, device=device, dataloaders=dataloaders,
                          dataset_sizes=dataset_sizes, num_epochs=NUM_OF_EPOCHS, conceptual_loss=conceptual_loss)
# Out:
# Epoch 0/24
# ----------
# train Loss: 0.8522 Acc: 0.5909
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 3
#       1 # pydev_debug_cell
#       2 concept_key = ts.get_concept_keys(experimental_sets=experimental_set_rand)
# ----> 3 model_ft = ms.train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler, device=device, dataloaders=dataloaders,
#       4                           dataset_sizes=dataset_sizes, num_epochs=25, include_tcav_loss=True, tcav_calc=mytcav,
#       5                           experimental_set_rand=experimental_set_rand, layers=layers, target_concept=target_concept,
#       6                           concept_key=concept_key)
#
# File D:\git\COMP-5900\Project\Model_support.py:131, in train_model(model, criterion, optimizer, scheduler, device, dataloaders, dataset_sizes, num_epochs, include_tcav_loss, tcav_calc, experimental_set_rand, layers, target_concept, concept_key)
#     128         pass
#     130 # Get the standard loss
# --> 131 outputs = model(inputs)
#     132 _, preds = torch.max(outputs, 1)
#     133 loss = criterion(outputs, labels)
#
# File D:\git\COMP-5900\Project\Model_support.py:131, in train_model(model, criterion, optimizer, scheduler, device, dataloaders, dataset_sizes, num_epochs, include_tcav_loss, tcav_calc, experimental_set_rand, layers, target_concept, concept_key)
#     128         pass
#     130 # Get the standard loss
# --> 131 outputs = model(inputs)
#     132 _, preds = torch.max(outputs, 1)
#     133 loss = criterion(outputs, labels)
#
# File _pydevd_bundle\pydevd_cython_win32_38_64.pyx:1179, in _pydevd_bundle.pydevd_cython_win32_38_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\pydevd_cython_win32_38_64.pyx:620, in _pydevd_bundle.pydevd_cython_win32_38_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_38_64.pyx:929, in _pydevd_bundle.pydevd_cython_win32_38_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_38_64.pyx:920, in _pydevd_bundle.pydevd_cython_win32_38_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_38_64.pyx:317, in _pydevd_bundle.pydevd_cython_win32_38_64.PyDBFrame.do_wait_suspend()
#
# File D:\Programs\JetBrains\PyCharm 2020.3.3\plugins\python\helpers\pydev\pydevd.py:1141, in PyDB.do_wait_suspend(self, thread, frame, event, arg, send_suspend_message, is_unhandled_exception)
#    1138         from_this_thread.append(frame_id)
#    1140 with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1141     self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread)
#
# File D:\Programs\JetBrains\PyCharm 2020.3.3\plugins\python\helpers\pydev\pydevd.py:1156, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread)
#    1153             self._call_mpl_hook()
#    1155         self.process_internal_commands()
# -> 1156         time.sleep(0.01)
#    1158 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    1160 # process any stepping instructions
#
# KeyboardInterrupt:

# %% [markdown]
# # Visualizing the TCAV Score

# %%
ms.visualize_model(model_ft, device=device, dataloaders=dataloaders, class_names=class_names)

# %%
experimental_set_zig_dot = [[stripes_concept, zigzagged_concept, dotted_concept]]

tcav_scores_w_zig_dot = mytcav.interpret(inputs=zebra_tensors,
                                         experimental_sets=experimental_set_zig_dot,
                                         target=zebra_ind,
                                         n_steps=5)

ts.plot_tcav_scores(experimental_set_zig_dot, tcav_scores_w_zig_dot, layers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 4
#       1 # pydev_debug_cell
#       2 experimental_set_zig_dot = [[stripes_concept, zigzagged_concept, dotted_concept]]
# ----> 4 tcav_scores_w_zig_dot = mytcav.interpret(inputs=zebra_tensors,
#       5                                          experimental_sets=experimental_set_zig_dot,
#       6                                          target=zebra_ind,
#       7                                          n_steps=5)
#       9 ts.plot_tcav_scores(experimental_set_zig_dot, tcav_scores_w_zig_dot, layers)
#
# NameError: name 'zebra_tensors' is not defined

# %%
# Visualization of various concepts
n_figs = 5
n_concepts = 5

fig, axs = plt.subplots(n_concepts, n_figs + 1, figsize = (25, 4 * n_concepts))

for c, concept in enumerate([stripes_concept, zigzagged_concept, dotted_concept, random_0_concept, random_1_concept]):
    concept_path = os.path.join(concepts_path, concept.name) + "/"
    img_files = glob.glob(concept_path + '*')
    for i, img_file in enumerate(img_files[:n_figs + 1]):
        if os.path.isfile(img_file):
            if i == 0:
                axs[c, i].text(1.0, 0.5, str(concept.name), ha='right', va='center', family='sans-serif', size=24)
            else:
                img = plt.imread(img_file)
                axs[c, i].imshow(img)

            axs[c, i].axis('off')

# %%
# Visualization of classes

# Visualize some of the images
fig, axs = plt.subplots(1, 6, figsize = (25, 5))
axs[0].imshow(zebra_imgs[40])
axs[1].imshow(zebra_imgs[41])
axs[2].imshow(ant_imgs[34])
axs[3].imshow(ant_imgs[31])
axs[4].imshow(bee_imgs[30])
axs[5].imshow(bee_imgs[31])

axs[0].axis('off')
axs[1].axis('off')
axs[2].axis('off')
axs[3].axis('off')
axs[4].axis('off')
axs[5].axis('off')

plt.show()
